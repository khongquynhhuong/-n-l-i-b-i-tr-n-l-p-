# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Ví dụ về hàm
# Hàm tính tổng 2 số 
def sum(a,b):
    return a+b
print(sum(15,5))
# Out:
# 20

# %%
#ví dụ : Hàm in ra một chuỗi số  "Hello Python Fundamental"
def say_hello():
    print("Hello Python Fundamentals")
say_hello()
# Out:
# Hello Python Fundamentals

# %%
# Thực hành : hãy viết hàm kiểm tra một số nhập vào từ bàn phím có phải số nguyên tố hay không
# Out:
# Enter a number: 13
# 13 is a prime number

# %% [markdown]
# ### Viết hàm nhận vào số lương vòng tròn và vẽ ra hình ảnh như dưới dây:
# ![image.png](attachment:image.png)
